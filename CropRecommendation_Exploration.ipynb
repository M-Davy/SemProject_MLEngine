# %% [markdown]
# # Crop Recommendation Dataset Exploration
# **Deliverable:** Project Deliverable 1
#
# **Project:** Smart Farm Management System

# %% [markdown]
# ## Datasets Discovered and Output Variable
#
# 1. **Crop Recommendation Dataset** (Kaggle: atharvaingle/crop-recommendation-dataset) — N, P, K, temperature, humidity, ph, rainfall → output: label (recommended crop)
# 2. **Fertilizer Prediction Dataset** (Kaggle: gdabhishek/fertilizer-prediction) — soil/crop/climate data → output: Fertilizer Name
# 3. **PlantVillage Dataset** (github.com/spMohanty/PlantVillage-Dataset) — leaf images → output: disease/healthy class
#
# ## Selected Dataset for This Deliverable
#
# We selected the **Crop Recommendation Dataset** because it is a clean tabular CSV file that directly supports the exploration questions required (rows/columns, datatypes, missing values, row slicing). The other two datasets will be explored when we build their respective modules.
#
# In addition, recommending the right crop is the first decision a farmer makes before fertilizer or disease management even become relevant, it is the natural entry point for our Smart Farm Management System.
#
# Besides, all seven input variables (N, P, K, temperature, humidity, ph, rainfall) are measurements a farmer can reasonably obtain — either through a basic soil test or from weather data pulled automatically via the mobile app's location, making the dataset practical, not just theoretical.

# %%
import os
from getpass import getpass

os.environ["KAGGLE_API_TOKEN"] = getpass("Paste your Kaggle API token here: ")
# Out:
# Paste your Kaggle API token here: ··········

# %%
# !pip install -q kaggle
# !kaggle datasets download -d atharvaingle/crop-recommendation-dataset -p /content --unzip
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/atharvaingle/crop-recommendation-dataset
# License(s): apache-2.0
# ...
# 100% 63.7k/63.7k [00:00<00:00, 352kB/s]

# %%
import pandas as pd

df = pd.read_csv("/content/Crop_recommendation.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
num_rows, num_cols = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
# Out:
# Number of rows: 2200
# Number of columns: 8

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
missing_per_column = df.isnull().sum()
print(missing_per_column)

total_missing = df.isnull().sum().sum()
if total_missing == 0:
    print("\nThe dataset is complete — there are no missing values.")
else:
    print(f"\nThe dataset has {total_missing} missing values in total.")
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64
#
# The dataset is complete — there are no missing values.

# %%
first_15 = df.head(15)
last_20 = df.tail(20)

df_sample = pd.concat([first_15, last_20], ignore_index=True)
df_sample
# Out:
#       N   P   K  temperature   humidity        ph    rainfall   label
# 0    90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1    85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2    60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3    74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4    78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# 5    69  37  42    23.058049  83.370118  7.073454  251.055000    rice
# 6    69  55  38    22.708838  82.639414  5.700806  271.324860    rice
# 7    94  53  40    20.277744  82.894086  5.718627  241.974195    rice
# 8    89  54  38    24.515881  83.535216  6.685346  230.446236    rice
# 9    68  58  38    23.223974  83.033227  6.336254  221.209196    rice
# 10   91  53  40    26.527235  81.417538  5.386168  264.614870    rice
# 11   90  46  42    23.978982  81.450616  7.502834  250.083234    rice
# ...
